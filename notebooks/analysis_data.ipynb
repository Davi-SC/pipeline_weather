# %% [markdown]
# # Exploração dos dados

# %%
path = '../data/weather_data.json'

import pandas as pd
import json

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 804, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id         name  cod  coord.lon  coord.lat  ...  \
# 0  1771356395    -10800  3401992  Coelho Neto  200   -43.0128    -4.2567  ...
#
#    main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# 0             75            1008              999        1.41       196
#
#    wind.gust  clouds.all  sys.country  sys.sunrise  sys.sunset
# 0       3.18         100           BR   1771318751  1771362794
#
# [1 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   weather          1 non-null      object
#  1   base             1 non-null      str
#  2   visibility       1 non-null      int64
#  3   dt               1 non-null      int64
#  4   timezone         1 non-null      int64
#  5   id               1 non-null      int64
#  6   name             1 non-null      str
#  7   cod              1 non-null      int64
#  8   coord.lon        1 non-null      float64
#  9   coord.lat        1 non-null      float64
#  10  main.temp        1 non-null      float64
#  11  main.feels_like  1 non-null      float64
#  12  main.temp_min    1 non-null      float64
#  13  main.temp_max    1 non-null      float64
#  14  main.pressure    1 non-null      int64
#  15  main.humidity    1 non-null      int64
#  16  main.sea_level   1 non-null      int64
#  17  main.grnd_level  1 non-null      int64
#  18  wind.speed       1 non-null      float64
#  19  wind.deg         1 non-null      int64
#  20  wind.gust        1 non-null      float64
#  21  clouds.all       1 non-null      int64
#  22  sys.country      1 non-null      str
#  23  sys.sunrise      1 non-null      int64
#  24  sys.sunset       1 non-null      int64
# dtypes: float64(8), int64(13), object(1), str(3)
# memory usage: 332.0+ bytes

# %%
df.describe()
# Out:
#        visibility            dt  timezone         id    cod  coord.lon  \
# count         1.0  1.000000e+00       1.0        1.0    1.0     1.0000
# mean      10000.0  1.771356e+09  -10800.0  3401992.0  200.0   -43.0128
# std           NaN           NaN       NaN        NaN    NaN        NaN
# min       10000.0  1.771356e+09  -10800.0  3401992.0  200.0   -43.0128
# 25%       10000.0  1.771356e+09  -10800.0  3401992.0  200.0   -43.0128
# 50%       10000.0  1.771356e+09  -10800.0  3401992.0  200.0   -43.0128
# 75%       10000.0  1.771356e+09  -10800.0  3401992.0  200.0   -43.0128
# max       10000.0  1.771356e+09  -10800.0  3401992.0  200.0   -43.0128
#
#        coord.lat  main.temp  main.feels_like  main.temp_min  ...  \
# count     1.0000       1.00             1.00           1.00  ...
# mean     -4.2567      28.25            31.92          28.25  ...
# std          NaN        NaN              NaN            NaN  ...
# min      -4.2567      28.25            31.92          28.25  ...
# 25%      -4.2567      28.25            31.92          28.25  ...
# 50%      -4.2567      28.25            31.92          28.25  ...
# 75%      -4.2567      28.25            31.92          28.25  ...
# max      -4.2567      28.25            31.92          28.25  ...
#
#        main.pressure  main.humidity  main.sea_level  main.grnd_level  \
# count            1.0            1.0             1.0              1.0
# mean          1008.0           75.0          1008.0            999.0
# std              NaN            NaN             NaN              NaN
# min           1008.0           75.0          1008.0            999.0
# 25%           1008.0           75.0          1008.0            999.0
# 50%           1008.0           75.0          1008.0            999.0
# 75%           1008.0           75.0          1008.0            999.0
# max           1008.0           75.0          1008.0            999.0
#
#        wind.speed  wind.deg  wind.gust  clouds.all   sys.sunrise    sys.sunset
# count        1.00       1.0       1.00         1.0  1.000000e+00  1.000000e+00
# mean         1.41     196.0       3.18       100.0  1.771319e+09  1.771363e+09
# std           NaN       NaN        NaN         NaN           NaN           NaN
# min          1.41     196.0       3.18       100.0  1.771319e+09  1.771363e+09
# 25%          1.41     196.0       3.18       100.0  1.771319e+09  1.771363e+09
# 50%          1.41     196.0       3.18       100.0  1.771319e+09  1.771363e+09
# 75%          1.41     196.0       3.18       100.0  1.771319e+09  1.771363e+09
# max          1.41     196.0       3.18       100.0  1.771319e+09  1.771363e+09
#
# [8 rows x 21 columns]

# %%
from sqlalchemy import create_engine
import os
from urllib.parse import quote_plus

from dotenv import load_dotenv

load_dotenv("../config/.env")
user = os.getenv('USER')
password = quote_plus(os.getenv('PASSWORD'))
database = os.getenv('DATABASE')
host = os.getenv('HOST')

engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:5432/{database}")
engine.connect()
print("Conectou 🎉")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[16], line 14
#      11 host = os.getenv('HOST')
#      13 engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:5432/{database}")
# ---> 14 engine.connect()
#      15 print("Conectou 🎉")
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3285, in Engine.connect(self)
#    3262 def connect(self) -> Connection:
#    3263     """Return a new :class:`_engine.Connection` object.
#    3264
#    3265     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3282
#    3283     """
# -> 3285     return self._connection_cls(self)
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3309, in Engine.raw_connection(self)
#    3287 def raw_connection(self) -> PoolProxiedConnection:
#    3288     """Return a "raw" DBAPI connection from the connection pool.
#    3289
#    3290     The returned object is a proxied version of the DBAPI
#    (...)   3307
#    3308     """
# -> 3309     return self.pool.connect()
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     439 def connect(self) -> PoolProxiedConnection:
#     440     """Return a DBAPI connection from the pool.
#     441
#     442     The connection is instrumented such that when its
#    (...)    445
#     446     """
# --> 447     return _ConnectionFairy._checkout(self)
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     709     rec = cast(_ConnectionRecord, pool._do_get())
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#     714     dbapi_connection = rec.get_connection()
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\base.py:388, in Pool._create_connection(self)
#     385 def _create_connection(self) -> ConnectionPoolEntry:
#     386     """Called by subclasses to create a new ConnectionRecord."""
# --> 388     return _ConnectionRecord(self)
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     671 self.__pool = pool
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\base.py:899, in _ConnectionRecord.__connect(self)
#     897     self.fresh = True
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#     901 else:
#     902     # in SQLAlchemy 1.4 the first_connect event is not used by
#     903     # the engine, so this will usually not be set
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\pool\base.py:895, in _ConnectionRecord.__connect(self)
#     893 try:
#     894     self.starttime = time.time()
# --> 895     self.dbapi_connection = connection = pool._invoke_creator(self)
#     896     pool.logger.debug("Created new connection %r", connection)
#     897     self.fresh = True
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\engine\create.py:661, in create_engine.<locals>.connect(connection_record)
#     658         if connection is not None:
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Projects\pipeline_weather\.venv\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
#     137     conn.cursor_factory = cursor_factory
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 78: invalid continuation byte

# %%
from dotenv import load_dotenv
import os

load_dotenv("../config/.env")

pwd = os.getenv("PASSWORD")

print(pwd)
print(repr(pwd))
print([hex(ord(c)) for c in pwd])
# Out:
# 123
# '123'
# ['0x31', '0x32', '0x33']
